# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
import pandas as pd # Import pandas with alias pd
data = pd.read_csv('/content/spambase.data', header=None) # Use read_csv and specify header=None if the file has no header row

# %%
# Split the data into features (X) and target (y)
# Assuming 'spam' is the last column (index 57) as it's common in spam datasets
X = data.drop(columns=[57])  # Drop the column by its index
y = data[57]  # Select the target column by its index

# %%
# Scale the features using MinMaxScaler
scaler = MinMaxScaler() # Create a MinMaxScaler object
X_scaled = scaler.fit_transform(X) # Fit the scaler to X and transform it, storing the result in X_scaled

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Initialize the Naive Bayes classifier
nb_classifier = MultinomialNB()
nb_classifier= ga

# %%
# Train the model on the training data
nb_classifier.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on the test data
y_pred = nb_classifier.predict(X_test)

# %%
# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

# Generate a classification report
classification_report_output = classification_report(y_test, y_pred)

# Output the accuracy and classification report
print(f"Accuracy: {accuracy * 100:.2f}%")
print("Classification Report:")
print(classification_report_output)
# Out:
# Accuracy: 87.19%
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90       531
#            1       0.95      0.74      0.83       390
#
#     accuracy                           0.87       921
#    macro avg       0.89      0.85      0.86       921
# weighted avg       0.88      0.87      0.87       921

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns


# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred) # Calculate and store the confusion matrix

plt.figure(figsize=(8,6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=['Not Spam', 'Spam'], yticklabels=['Not Spam', 'Spam'])
plt.title(f'Confusion Matrix (Accuracy: {accuracy * 100:.2f}%)')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# # New Section
